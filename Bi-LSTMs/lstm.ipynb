# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip uninstall tensorflow
# !pip install tensorflow==1.13.2
# Out:
# Found existing installation: tensorflow 2.8.0
# Uninstalling tensorflow-2.8.0:
#   Would remove:
#     /usr/local/bin/estimator_ckpt_converter
#     /usr/local/bin/import_pb_to_tensorboard
#     /usr/local/bin/saved_model_cli
#     /usr/local/bin/tensorboard
#     /usr/local/bin/tf_upgrade_v2
#     /usr/local/bin/tflite_convert
#     /usr/local/bin/toco
#     /usr/local/bin/toco_from_protos
#     /usr/local/lib/python3.7/dist-packages/tensorflow-2.8.0.dist-info/*
#     /usr/local/lib/python3.7/dist-packages/tensorflow/*
# Proceed (y/n)? y
# y
#   Successfully uninstalled tensorflow-2.8.0
# Collecting tensorflow==1.13.2
#   Downloading tensorflow-1.13.2-cp37-cp37m-manylinux1_x86_64.whl (92.7 MB)
#      |████████████████████████████████| 92.7 MB 1.2 MB/s
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.1.2)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (0.37.1)
# Collecting keras-applications>=1.0.6
#   Downloading Keras_Applications-1.0.8-py3-none-any.whl (50 kB)
#      |████████████████████████████████| 50 kB 6.2 MB/s
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.1.0)
# Requirement already satisfied: absl-py>=0.1.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.0.0)
# Collecting tensorboard<1.14.0,>=1.13.0
#   Downloading tensorboard-1.13.1-py3-none-any.whl (3.2 MB)
#      |████████████████████████████████| 3.2 MB 59.9 MB/s
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.21.6)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.15.0)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (3.17.3)
# Collecting tensorflow-estimator<1.14.0rc0,>=1.13.0
#   Downloading tensorflow_estimator-1.13.0-py2.py3-none-any.whl (367 kB)
#      |████████████████████████████████| 367 kB 75.7 MB/s
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (1.44.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (0.8.1)
# Requirement already satisfied: gast>=0.2.0 in /usr/local/lib/python3.7/dist-packages (from tensorflow==1.13.2) (0.5.3)
# Requirement already satisfied: h5py in /usr/local/lib/python3.7/dist-packages (from keras-applications>=1.0.6->tensorflow==1.13.2) (3.1.0)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (3.3.6)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.7/dist-packages (from tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (1.0.1)
# Requirement already satisfied: importlib-metadata>=4.4 in /usr/local/lib/python3.7/dist-packages (from markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (4.11.3)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (4.2.0)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard<1.14.0,>=1.13.0->tensorflow==1.13.2) (3.8.0)
# Collecting mock>=2.0.0
#   Downloading mock-4.0.3-py3-none-any.whl (28 kB)
# Requirement already satisfied: cached-property in /usr/local/lib/python3.7/dist-packages (from h5py->keras-applications>=1.0.6->tensorflow==1.13.2) (1.5.2)
# Installing collected packages: mock, tensorflow-estimator, tensorboard, keras-applications, tensorflow
#   Attempting uninstall: tensorflow-estimator
#     Found existing installation: tensorflow-estimator 2.8.0
#     Uninstalling tensorflow-estimator-2.8.0:
#       Successfully uninstalled tensorflow-estimator-2.8.0
#   Attempting uninstall: tensorboard
#     Found existing installation: tensorboard 2.8.0
#     Uninstalling tensorboard-2.8.0:
#       Successfully uninstalled tensorboard-2.8.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# kapre 0.3.7 requires tensorflow>=2.0.0, but you have tensorflow 1.13.2 which is incompatible.
# Successfully installed keras-applications-1.0.8 mock-4.0.3 tensorboard-1.13.1 tensorflow-1.13.2 tensorflow-estimator-1.13.0

# %%
import tensorflow as tf
import os
from tensorflow.python.keras.layers import Layer
from tensorflow.python.keras import backend as K


class AttentionLayer(Layer):
    """
    This class implements Bahdanau attention (https://arxiv.org/pdf/1409.0473.pdf).
    There are three sets of weights introduced W_a, U_a, and V_a
     """

    def __init__(self, **kwargs):
        super(AttentionLayer, self).__init__(**kwargs)

    def build(self, input_shape):
        assert isinstance(input_shape, list)
        # Create a trainable weight variable for this layer.

        self.W_a = self.add_weight(name='W_a',
                                   shape=tf.TensorShape((input_shape[0][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.U_a = self.add_weight(name='U_a',
                                   shape=tf.TensorShape((input_shape[1][2], input_shape[0][2])),
                                   initializer='uniform',
                                   trainable=True)
        self.V_a = self.add_weight(name='V_a',
                                   shape=tf.TensorShape((input_shape[0][2], 1)),
                                   initializer='uniform',
                                   trainable=True)

        super(AttentionLayer, self).build(input_shape)  # Be sure to call this at the end

    def call(self, inputs, verbose=False):
        """
        inputs: [encoder_output_sequence, decoder_output_sequence]
        """
        assert type(inputs) == list
        encoder_out_seq, decoder_out_seq = inputs
        if verbose:
            print('encoder_out_seq>', encoder_out_seq.shape)
            print('decoder_out_seq>', decoder_out_seq.shape)

        def energy_step(inputs, states):
            """ Step function for computing energy for a single decoder state """

            assert_msg = "States must be a list. However states {} is of type {}".format(states, type(states))
            assert isinstance(states, list) or isinstance(states, tuple), assert_msg

            """ Some parameters required for shaping tensors"""
            en_seq_len, en_hidden = encoder_out_seq.shape[1], encoder_out_seq.shape[2]
            de_hidden = inputs.shape[-1]

            """ Computing S.Wa where S=[s0, s1, ..., si]"""
            # <= batch_size*en_seq_len, latent_dim
            reshaped_enc_outputs = K.reshape(encoder_out_seq, (-1, en_hidden))
            # <= batch_size*en_seq_len, latent_dim
            W_a_dot_s = K.reshape(K.dot(reshaped_enc_outputs, self.W_a), (-1, en_seq_len, en_hidden))
            if verbose:
                print('wa.s>',W_a_dot_s.shape)

            """ Computing hj.Ua """
            U_a_dot_h = K.expand_dims(K.dot(inputs, self.U_a), 1)  # <= batch_size, 1, latent_dim
            if verbose:
                print('Ua.h>',U_a_dot_h.shape)

            """ tanh(S.Wa + hj.Ua) """
            # <= batch_size*en_seq_len, latent_dim
            reshaped_Ws_plus_Uh = K.tanh(K.reshape(W_a_dot_s + U_a_dot_h, (-1, en_hidden)))
            if verbose:
                print('Ws+Uh>', reshaped_Ws_plus_Uh.shape)

            """ softmax(va.tanh(S.Wa + hj.Ua)) """
            # <= batch_size, en_seq_len
            e_i = K.reshape(K.dot(reshaped_Ws_plus_Uh, self.V_a), (-1, en_seq_len))
            # <= batch_size, en_seq_len
            e_i = K.softmax(e_i)

            if verbose:
                print('ei>', e_i.shape)

            return e_i, [e_i]

        def context_step(inputs, states):
            """ Step function for computing ci using ei """
            # <= batch_size, hidden_size
            c_i = K.sum(encoder_out_seq * K.expand_dims(inputs, -1), axis=1)
            if verbose:
                print('ci>', c_i.shape)
            return c_i, [c_i]

        def create_inital_state(inputs, hidden_size):
            # We are not using initial states, but need to pass something to K.rnn funciton
            fake_state = K.zeros_like(inputs)  # <= (batch_size, enc_seq_len, latent_dim
            fake_state = K.sum(fake_state, axis=[1, 2])  # <= (batch_size)
            fake_state = K.expand_dims(fake_state)  # <= (batch_size, 1)
            fake_state = K.tile(fake_state, [1, hidden_size])  # <= (batch_size, latent_dim
            return fake_state

        fake_state_c = create_inital_state(encoder_out_seq, encoder_out_seq.shape[-1])
        fake_state_e = create_inital_state(encoder_out_seq, encoder_out_seq.shape[1])  # <= (batch_size, enc_seq_len, latent_dim

        """ Computing energy outputs """
        # e_outputs => (batch_size, de_seq_len, en_seq_len)
        last_out, e_outputs, _ = K.rnn(
            energy_step, decoder_out_seq, [fake_state_e],
        )

        """ Computing context vectors """
        last_out, c_outputs, _ = K.rnn(
            context_step, e_outputs, [fake_state_c],
        )

        return c_outputs, e_outputs

    def compute_output_shape(self, input_shape):
        """ Outputs produced by the layer """
        return [
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[1][2])),
            tf.TensorShape((input_shape[1][0], input_shape[1][1], input_shape[0][1]))
        ]
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/framework/dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])

# %%
import numpy as np
import pandas as pd 
import re
from tensorflow.keras.preprocessing.text import Tokenizer 
from nltk import download
download('stopwords')
from nltk.corpus import stopwords
from tensorflow.keras.layers import Input, LSTM, Embedding, Dense, Concatenate, TimeDistributed
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import EarlyStopping
from tensorflow import keras
import warnings
# from attention import AttentionLayer
pd.set_option("display.max_colwidth", 200)
warnings.filterwarnings("ignore")
print(tf.version.VERSION)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# 1.13.2

# %%
checkpoint_path = "/content/drive/MyDrive/Colab Notebooks/cp.ckpt"
checkpoint_dir = os.path.dirname(checkpoint_path)

# Create a callback that saves the model's weights
cp_callback = tf.keras.callbacks.ModelCheckpoint(filepath=checkpoint_path,
                                                 save_weights_only=True,
                                                 verbose=1)

# %%
reviews = pd.read_excel("/content/drive/MyDrive/Colab Notebooks/data/Inshorts_Data.xlsx")
print(reviews.shape)
reviews.head()
# Out:
# (55104, 5)
#                                                        Headline  \
# 0    4 ex-bank officials booked for cheating bank of ₹209 crore
# 1                Supreme Court to go paperless in 6 months: CJI
# 2  At least 3 killed, 30 injured in blast in Sylhet, Bangladesh
# 3         Why has Reliance been barred from trading in futures?
# 4   Was stopped from entering my own studio at Times Now: Arnab
#
#                                                                                                                                                                                                      Short  \
# 0  The CBI on Saturday booked four former officials of Syndicate Bank and six others for cheating, forgery, criminal conspiracy and causing ₹209 crore loss to the state-run bank. The accused had avai...
# 1  Chief Justice JS Khehar has said the Supreme Court will go paperless in six to seven months in a bid to save funds and make the judiciary eco-friendly. He further said the apex court will collect ...
# 2  At least three people were killed, including a policeman, while 30 others were wounded on Saturday evening in two explosions in Sylhet, Bangladesh. The explosions were targetted at people and poli...
# 3  Mukesh Ambani-led Reliance Industries (RIL) was barred from trading in futures market for a year over stake sale in Reliance Petroleum (RPL). In 2007, RIL sold 4.1% stake in RPL, but shares were f...
# 4  TV news anchor Arnab Goswami has said he was told he could not do the programme two days before leaving Times Now. &#34;18th November was my last day, I was not allowed to enter my own studio,&#34...
#
#                   Source      Time  Publish Date
# 0  The New Indian Express  09:25:00   2017-03-26
# 1                 Outlook  22:18:00   2017-03-25
# 2         Hindustan Times  23:39:00   2017-03-25
# 3                Livemint  23:08:00   2017-03-25
# 4                 YouTube  23:24:00   2017-03-25

# %%
# Check for any nulls values
reviews.isnull().sum()
# Out:
# Headline        0
# Short           0
# Source          0
# Time            0
# Publish Date    0
# dtype: int64

# %%
# let's inspect some reviews
for i in range(5):
    print("Review: ",i+1)
    print(reviews.Headline[i])
    print('-'*80)
    print(reviews.Short[i])
    print()
# Out:
# Review:  1
# 4 ex-bank officials booked for cheating bank of ₹209 crore
# --------------------------------------------------------------------------------
# The CBI on Saturday booked four former officials of Syndicate Bank and six others for cheating, forgery, criminal conspiracy and causing ₹209 crore loss to the state-run bank. The accused had availed home loans and credit from Syndicate Bank on the basis of forged and fabricated documents. These funds were fraudulently transferred to the companies owned by the accused persons.
#
# Review:  2
# Supreme Court to go paperless in 6 months: CJI
# --------------------------------------------------------------------------------
# Chief Justice JS Khehar has said the Supreme Court will go paperless in six to seven months in a bid to save funds and make the judiciary eco-friendly. He further said the apex court will collect all the records electronically from the lower courts and the high courts so that there is no need to file hard copies.
#
# Review:  3
# At least 3 killed, 30 injured in blast in Sylhet, Bangladesh
# --------------------------------------------------------------------------------
# At least three people were killed, including a policeman, while 30 others were wounded on Saturday evening in two explosions in Sylhet, Bangladesh. The explosions were targetted at people and police officials who were witnessing an over 30-hour-long gunfight between extremists and commandos. Earlier on Friday, a man had blown himself up in front of a checkpoint near Dhaka Airport.
#
# Review:  4
# Why has Reliance been barred from trading in futures?
# --------------------------------------------------------------------------------
# Mukesh Ambani-led Reliance Industries (RIL) was barred from trading in futures market for a year over stake sale in Reliance Petroleum (RPL). In 2007, RIL sold 4.1% stake in RPL, but shares were first &#39;short-sold&#39; in futures market to avoid a fall in RPL stocks. Short sale means selling shares with plans to buy them back later at lower prices.
#
# Review:  5
# Was stopped from entering my own studio at Times Now: Arnab
# --------------------------------------------------------------------------------
# TV news anchor Arnab Goswami has said he was told he could not do the programme two days before leaving Times Now. &#34;18th November was my last day, I was not allowed to enter my own studio,&#34; Goswami added. &#34;When you build an institution and are not allowed to enter your own studio, you feel sad,&#34; the journalist further said.

# %% [markdown]
# # Lets cleaned datasets

# %%
# Compile a regular expression pattern into a regular expression object, which can be used for matching using its match(), search() and other methods, described below.

CURRENCIES = {
    "$": "USD", "zł": "PLN", "£": "GBP", "¥": "JPY", "฿": "THB", "₡": "CRC", "₦": "NGN","₩": "KRW",
    "₪": "ILS", "₫": "VND", "€": "EUR", "₱": "PHP", "₲": "PYG", "₴": "UAH", "₹": "INR",}
CURRENCY_REGEX = re.compile(
    "({})+".format("|".join(re.escape(c) for c in CURRENCIES.keys())))

EMAIL_REGEX = re.compile(
    r"(?:^|(?<=[^\w@.)]))([\w+-](\.(?!\.))?)*?[\w+-]@(?:\w-?)*?\w+(\.([a-z]{2,})){1,3}(?:$|(?=\b))",
    flags=re.IGNORECASE | re.UNICODE,)

# A list of contractions from http://stackoverflow.com/questions/19790188/expanding-english-language-contractions-in-python
contractions =          {"ain't": "is not", "aren't": "are not","can't": "cannot", "'cause": "because", "could've": "could have", "couldn't": "could not",
                           "didn't": "did not",  "doesn't": "does not", "don't": "do not", "hadn't": "had not", "hasn't": "has not", "haven't": "have not",
                           "he'd": "he would","he'll": "he will", "he's": "he is", "how'd": "how did", "how'd'y": "how do you", "how'll": "how will", "how's": "how is",
                           "I'd": "I would", "I'd've": "I would have", "I'll": "I will", "I'll've": "I will have","I'm": "I am", "I've": "I have", "i'd": "i would",
                           "i'd've": "i would have", "i'll": "i will",  "i'll've": "i will have","i'm": "i am", "i've": "i have", "isn't": "is not", "it'd": "it would",
                           "it'd've": "it would have", "it'll": "it will", "it'll've": "it will have","it's": "it is", "let's": "let us", "ma'am": "madam",
                           "mayn't": "may not", "might've": "might have","mightn't": "might not","mightn't've": "might not have", "must've": "must have",
                           "mustn't": "must not", "mustn't've": "must not have", "needn't": "need not", "needn't've": "need not have","o'clock": "of the clock",
                           "oughtn't": "ought not", "oughtn't've": "ought not have", "shan't": "shall not", "sha'n't": "shall not", "shan't've": "shall not have",
                           "she'd": "she would", "she'd've": "she would have", "she'll": "she will", "she'll've": "she will have", "she's": "she is",
                           "should've": "should have", "shouldn't": "should not", "shouldn't've": "should not have", "so've": "so have","so's": "so as",
                           "this's": "this is","that'd": "that would", "that'd've": "that would have", "that's": "that is", "there'd": "there would",
                           "there'd've": "there would have", "there's": "there is", "here's": "here is","they'd": "they would", "they'd've": "they would have",
                           "they'll": "they will", "they'll've": "they will have", "they're": "they are", "they've": "they have", "to've": "to have",
                           "wasn't": "was not", "we'd": "we would", "we'd've": "we would have", "we'll": "we will", "we'll've": "we will have", "we're": "we are",
                           "we've": "we have", "weren't": "were not", "what'll": "what will", "what'll've": "what will have", "what're": "what are",
                           "what's": "what is", "what've": "what have", "when's": "when is", "when've": "when have", "where'd": "where did", "where's": "where is",
                           "where've": "where have", "who'll": "who will", "who'll've": "who will have", "who's": "who is", "who've": "who have",
                           "why's": "why is", "why've": "why have", "will've": "will have", "won't": "will not", "won't've": "will not have",
                           "would've": "would have", "wouldn't": "would not", "wouldn't've": "would not have", "y'all": "you all",
                           "y'all'd": "you all would","y'all'd've": "you all would have","y'all're": "you all are","y'all've": "you all have",
                           "you'd": "you would", "you'd've": "you would have", "you'll": "you will", "you'll've": "you will have",
                           "you're": "you are", "you've": "you have", "i've": "i have"}

# %%
def clean_text(text, remove_stopwords = True):
    
    text = text.lower()
    if True:
        text = text.split()
        new_text = []
        for word in text:
            if word in contractions:
                new_text.append(contractions[word])
            else:
                new_text.append(word)
        text = " ".join(new_text)
        
    text = re.sub(r'https?:\/\/.*[\r\n]*', '', text, flags=re.MULTILINE)
    text = EMAIL_REGEX.sub(' ',text)
    text = CURRENCY_REGEX.sub(' ',text)
    text = ' '.join([contractions[t] if t in contractions else t for t in text.split(" ")])    
    text = re.sub(r'[_"\-;%()|+&=*%.,!?:#$@\[\]/]', ' ', text)
    text = re.sub(r"'s\b","", text)
    text = re.sub(r'&amp;', '', text) 
    
    if remove_stopwords:
        text = text.split()
        stops = set(stopwords.words("english"))
        text = [w for w in text if not w in stops]
        text = " ".join(text)

    return text

# %%
cleaned_headlines = []
cleaned_text = []

for headlines in reviews['Headline']:
    cleaned_headlines.append(clean_text(headlines, remove_stopwords=False))
print("Headlines are complete.")

for text in reviews['Short']:
    cleaned_text.append(clean_text(text))
print("Texts are complete.")
# Out:
# Headlines are complete.
# Texts are complete.

# %%
# let's inspect some clean reviews
for i in range(4):
    print("Review: ",i+1)
    print(cleaned_headlines[i])
    print('-'*80)
    print(cleaned_text[i])
    print()
# Out:
# Review:  1
# 4 ex bank officials booked for cheating bank of  209 crore
# --------------------------------------------------------------------------------
# cbi saturday booked four former officials syndicate bank six others cheating forgery criminal conspiracy causing 209 crore loss state run bank accused availed home loans credit syndicate bank basis forged fabricated documents funds fraudulently transferred companies owned accused persons
#
# Review:  2
# supreme court to go paperless in 6 months  cji
# --------------------------------------------------------------------------------
# chief justice js khehar said supreme court go paperless six seven months bid save funds make judiciary eco friendly said apex court collect records electronically lower courts high courts need file hard copies
#
# Review:  3
# at least 3 killed  30 injured in blast in sylhet  bangladesh
# --------------------------------------------------------------------------------
# least three people killed including policeman 30 others wounded saturday evening two explosions sylhet bangladesh explosions targetted people police officials witnessing 30 hour long gunfight extremists commandos earlier friday man blown front checkpoint near dhaka airport
#
# Review:  4
# why has reliance been barred from trading in futures
# --------------------------------------------------------------------------------
# mukesh ambani led reliance industries ril barred trading futures market year stake sale reliance petroleum rpl 2007 ril sold 4 1 stake rpl shares first 39 short sold 39 futures market avoid fall rpl stocks short sale means selling shares plans buy back later lower prices

# %%
# distribution of sequences
import matplotlib.pyplot as plt

text_word_count = []
headlines_word_count = []

for i in cleaned_text:
    text_word_count.append(len(i.split()))
for i in cleaned_headlines:
    headlines_word_count.append(len(i.split()))

length_df = pd.DataFrame({'Short': text_word_count, 'Headline': headlines_word_count})
length_df.hist(bins=15)
plt.show()

# %%
count = 0
for i in cleaned_text:
    if(len(i.split())<=55):
        count += 1
print(count/len(cleaned_text))
# Out:
# 0.9982396922183507

# %%
max_headlines_len=15
max_text_len=55

cleaned_text = np.array(cleaned_text)
cleaned_headlines = np.array(cleaned_headlines)

short_text=[]
short_headlines=[]

for i in range(len(cleaned_text)):
    
    if(len(cleaned_headlines[i].split())<=max_headlines_len and len(cleaned_text[i].split())<=max_text_len):
        short_text.append(cleaned_text[i])
        short_headlines.append(cleaned_headlines[i])

df=pd.DataFrame({'Short':short_text,'Headline':short_headlines})
df['Headline'] = df['Headline'].apply(lambda x : 'sostok '+ x + ' eostok')

from sklearn.model_selection import train_test_split
x_tr,x_val,y_tr,y_val=train_test_split(np.array(df['Short']),np.array(df['Headline']),test_size=0.1,random_state=0,shuffle=True)

# %%
df.head()
# Out:
#                                                                                                                                                                                                      Short  \
# 0  cbi saturday booked four former officials syndicate bank six others cheating forgery criminal conspiracy causing 209 crore loss state run bank accused availed home loans credit syndicate bank basi...
# 1  chief justice js khehar said supreme court go paperless six seven months bid save funds make judiciary eco friendly said apex court collect records electronically lower courts high courts need fil...
# 2  least three people killed including policeman 30 others wounded saturday evening two explosions sylhet bangladesh explosions targetted people police officials witnessing 30 hour long gunfight extr...
# 3  mukesh ambani led reliance industries ril barred trading futures market year stake sale reliance petroleum rpl 2007 ril sold 4 1 stake rpl shares first 39 short sold 39 futures market avoid fall r...
# 4  tv news anchor arnab goswami said told could programme two days leaving times 34 18th november last day allowed enter studio 34 goswami added 34 build institution allowed enter studio feel sad 34 ...
#
#                                                                      Headline
# 0    sostok 4 ex bank officials booked for cheating bank of  209 crore eostok
# 1                sostok supreme court to go paperless in 6 months  cji eostok
# 2  sostok at least 3 killed  30 injured in blast in sylhet  bangladesh eostok
# 3         sostok why has reliance been barred from trading in futures  eostok
# 4   sostok was stopped from entering my own studio at times now  arnab eostok

# %%
from tensorflow.keras.preprocessing.text import Tokenizer 
from tensorflow.keras.preprocessing.sequence import pad_sequences

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer() 
x_tokenizer.fit_on_texts(list(x_tr))

thresh=4
cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in x_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)

#prepare a tokenizer for reviews on training data
x_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
x_tokenizer.fit_on_texts(list(x_tr))

#convert text sequences into integer sequences
x_tr_seq    =   x_tokenizer.texts_to_sequences(x_tr) 
x_val_seq   =   x_tokenizer.texts_to_sequences(x_val)

#padding zero upto maximum length
x_tr    =   pad_sequences(x_tr_seq,  maxlen=max_text_len, padding='post')
x_val   =   pad_sequences(x_val_seq, maxlen=max_text_len, padding='post')

#size of vocabulary ( +1 for padding token)
x_voc   =  x_tokenizer.num_words + 1

x_voc
# Out:
# % of rare words in vocabulary: 62.39495500602281
# Total Coverage of rare words: 3.2316560822687883
# 26537

# %%
#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer()   
y_tokenizer.fit_on_texts(list(y_tr))

thresh=6
cnt=0
tot_cnt=0
freq=0
tot_freq=0

for key,value in y_tokenizer.word_counts.items():
    tot_cnt=tot_cnt+1
    tot_freq=tot_freq+value
    if(value<thresh):
        cnt=cnt+1
        freq=freq+value
    
print("% of rare words in vocabulary:",(cnt/tot_cnt)*100)
print("Total Coverage of rare words:",(freq/tot_freq)*100)

#prepare a tokenizer for reviews on training data
y_tokenizer = Tokenizer(num_words=tot_cnt-cnt) 
y_tokenizer.fit_on_texts(list(y_tr))

#convert text sequences into integer sequences
y_tr_seq    =   y_tokenizer.texts_to_sequences(y_tr) 
y_val_seq   =   y_tokenizer.texts_to_sequences(y_val) 

#padding zero upto maximum length
y_tr    =   pad_sequences(y_tr_seq, maxlen=max_headlines_len, padding='post')
y_val   =   pad_sequences(y_val_seq, maxlen=max_headlines_len, padding='post')

#size of vocabulary
y_voc  =   y_tokenizer.num_words +1

y_tokenizer.word_counts['sostok'],len(y_tr)
# Out:
# % of rare words in vocabulary: 71.31448536489714
# Total Coverage of rare words: 6.675052150273229
# (49457, 49457)

# %%
ind=[]
for i in range(len(y_tr)):
    cnt=0
    for j in y_tr[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_tr=np.delete(y_tr,ind, axis=0)
x_tr=np.delete(x_tr,ind, axis=0)

ind=[]
for i in range(len(y_val)):
    cnt=0
    for j in y_val[i]:
        if j!=0:
            cnt=cnt+1
    if(cnt==2):
        ind.append(i)

y_val=np.delete(y_val,ind, axis=0)
x_val=np.delete(x_val,ind, axis=0)

# %%
latent_dim = 200
embedding_dim=110

# Encoder
encoder_inputs = Input(shape=(max_text_len,))

#embedding layer
enc_emb =  Embedding(x_voc, embedding_dim,trainable=True)(encoder_inputs)

#encoder lstm 1
encoder_lstm1 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output1, state_h1, state_c1 = encoder_lstm1(enc_emb)

#encoder lstm 2
encoder_lstm2 = LSTM(latent_dim,return_sequences=True,return_state=True,dropout=0.4,recurrent_dropout=0.4)
encoder_output2, state_h2, state_c2 = encoder_lstm2(encoder_output1)

#encoder lstm 3
encoder_lstm3=LSTM(latent_dim, return_state=True, return_sequences=True,dropout=0.4,recurrent_dropout=0.4)
encoder_outputs, state_h, state_c= encoder_lstm3(encoder_output2)

# Set up the decoder, using `encoder_states` as initial state.
decoder_inputs = Input(shape=(None,))

#embedding layer
dec_emb_layer = Embedding(y_voc, embedding_dim,trainable=True)
dec_emb = dec_emb_layer(decoder_inputs)

decoder_lstm = LSTM(latent_dim, return_sequences=True, return_state=True,dropout=0.4,recurrent_dropout=0.2)
decoder_outputs,decoder_fwd_state, decoder_back_state = decoder_lstm(dec_emb,initial_state=[state_h, state_c])

# Attention layer
attn_layer = AttentionLayer(name='attention_layer')
attn_out, attn_states = attn_layer([encoder_outputs, decoder_outputs])

# Concat attention input and decoder LSTM output
decoder_concat_input = Concatenate(axis=-1, name='concat_layer')([decoder_outputs, attn_out])

#dense layer
decoder_dense =  TimeDistributed(Dense(y_voc, activation='softmax'))
decoder_outputs = decoder_dense(decoder_concat_input)

# Define the model 
model = Model([encoder_inputs, decoder_inputs], decoder_outputs)
#model.load_weights('/content/drive/MyDrive/Colab Notebooks/cp_sw.ckpt')

model.summary()
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/ops/resource_variable_ops.py:435: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/backend.py:4010: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, 55)           0
# __________________________________________________________________________________________________
# embedding (Embedding)           (None, 55, 110)      2919070     input_1[0][0]
# __________________________________________________________________________________________________
# lstm (LSTM)                     [(None, 55, 200), (N 248800      embedding[0][0]
# __________________________________________________________________________________________________
# input_2 (InputLayer)            (None, None)         0
# __________________________________________________________________________________________________
# lstm_1 (LSTM)                   [(None, 55, 200), (N 320800      lstm[0][0]
# __________________________________________________________________________________________________
# embedding_1 (Embedding)         (None, None, 110)    885170      input_2[0][0]
# __________________________________________________________________________________________________
# lstm_2 (LSTM)                   [(None, 55, 200), (N 320800      lstm_1[0][0]
# __________________________________________________________________________________________________
# lstm_3 (LSTM)                   [(None, None, 200),  248800      embedding_1[0][0]
#                                                                  lstm_2[0][1]
#                                                                  lstm_2[0][2]
# __________________________________________________________________________________________________
# attention_layer (AttentionLayer [(None, None, 200),  80200       lstm_2[0][0]
#                                                                  lstm_3[0][0]
# __________________________________________________________________________________________________
# concat_layer (Concatenate)      (None, None, 400)    0           lstm_3[0][0]
#                                                                  attention_layer[0][0]
# __________________________________________________________________________________________________
# time_distributed (TimeDistribut (None, None, 8047)   3226847     concat_layer[0][0]
# ==================================================================================================
# Total params: 8,250,487
# Trainable params: 8,250,487
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.load_weights(checkpoint_path)

# %%
model.compile(optimizer='rmsprop', loss='sparse_categorical_crossentropy')
es = EarlyStopping(monitor='val_loss', mode='min', verbose=1,patience=2)
history=model.fit([x_tr,y_tr[:,:-1]], y_tr.reshape(y_tr.shape[0],y_tr.shape[1], 1)[:,1:] ,epochs=50,callbacks=[cp_callback],batch_size=128, validation_data=([x_val,y_val[:,:-1]], y_val.reshape(y_val.shape[0],y_val.shape[1], 1)[:,1:]))
# Out:
# Train on 49457 samples, validate on 5496 samples
# Epoch 1/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.9056
# Epoch 00001: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# WARNING:tensorflow:From /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/network.py:1436: update_checkpoint_state (from tensorflow.python.training.checkpoint_management) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.train.CheckpointManager to manage checkpoints rather than manually editing the Checkpoint proto.
# 49457/49457 [==============================] - 1676s 34ms/sample - loss: 1.9056 - val_loss: 2.7373
# Epoch 2/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8920
# Epoch 00002: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1658s 34ms/sample - loss: 1.8919 - val_loss: 2.7425
# Epoch 3/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8813
# Epoch 00003: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1656s 33ms/sample - loss: 1.8813 - val_loss: 2.7388
# Epoch 4/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8760
# Epoch 00004: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1675s 34ms/sample - loss: 1.8761 - val_loss: 2.7375
# Epoch 5/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8704
# Epoch 00005: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1693s 34ms/sample - loss: 1.8703 - val_loss: 2.7369
# Epoch 6/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8643
# Epoch 00006: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1670s 34ms/sample - loss: 1.8643 - val_loss: 2.7377
# Epoch 7/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8621
# Epoch 00007: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1656s 33ms/sample - loss: 1.8622 - val_loss: 2.7398
# Epoch 8/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8560
# Epoch 00008: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1653s 33ms/sample - loss: 1.8558 - val_loss: 2.7329
# Epoch 9/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8527
# Epoch 00009: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1654s 33ms/sample - loss: 1.8529 - val_loss: 2.7387
# Epoch 10/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8485
# Epoch 00010: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1663s 34ms/sample - loss: 1.8485 - val_loss: 2.7434
# Epoch 11/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8417
# Epoch 00011: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1655s 33ms/sample - loss: 1.8418 - val_loss: 2.7406
# Epoch 12/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8362
# Epoch 00012: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1656s 33ms/sample - loss: 1.8362 - val_loss: 2.7405
# Epoch 13/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8340
# Epoch 00013: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1656s 33ms/sample - loss: 1.8341 - val_loss: 2.7376
# Epoch 14/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8315
# Epoch 00014: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1659s 34ms/sample - loss: 1.8317 - val_loss: 2.7404
# Epoch 15/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8264
# Epoch 00015: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1662s 34ms/sample - loss: 1.8267 - val_loss: 2.7324
# Epoch 16/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8239
# Epoch 00016: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1660s 34ms/sample - loss: 1.8240 - val_loss: 2.7343
# Epoch 17/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8193
# Epoch 00017: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1659s 34ms/sample - loss: 1.8193 - val_loss: 2.7329
# Epoch 18/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8154
# Epoch 00018: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1663s 34ms/sample - loss: 1.8153 - val_loss: 2.7350
# Epoch 19/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8119
# Epoch 00019: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1655s 33ms/sample - loss: 1.8122 - val_loss: 2.7351
# Epoch 20/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8072
# Epoch 00020: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1650s 33ms/sample - loss: 1.8072 - val_loss: 2.7422
# Epoch 21/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.8064
# Epoch 00021: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1668s 34ms/sample - loss: 1.8064 - val_loss: 2.7329
# Epoch 22/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7999
# Epoch 00022: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1674s 34ms/sample - loss: 1.8000 - val_loss: 2.7296
# Epoch 23/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7965
# Epoch 00023: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1679s 34ms/sample - loss: 1.7965 - val_loss: 2.7271
# Epoch 24/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7915
# Epoch 00024: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1648s 33ms/sample - loss: 1.7914 - val_loss: 2.7334
# Epoch 25/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7907
# Epoch 00025: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1648s 33ms/sample - loss: 1.7907 - val_loss: 2.7273
# Epoch 26/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7861
# Epoch 00026: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1668s 34ms/sample - loss: 1.7863 - val_loss: 2.7379
# Epoch 27/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7837
# Epoch 00027: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1704s 34ms/sample - loss: 1.7836 - val_loss: 2.7479
# Epoch 28/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7800
# Epoch 00028: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1747s 35ms/sample - loss: 1.7798 - val_loss: 2.7332
# Epoch 29/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7748
# Epoch 00029: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1748s 35ms/sample - loss: 1.7748 - val_loss: 2.7322
# Epoch 30/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7720
# Epoch 00030: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1746s 35ms/sample - loss: 1.7720 - val_loss: 2.7320
# Epoch 31/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7692
# Epoch 00031: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1762s 36ms/sample - loss: 1.7692 - val_loss: 2.7264
# Epoch 32/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7646
# Epoch 00032: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1789s 36ms/sample - loss: 1.7644 - val_loss: 2.7341
# Epoch 33/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7606
# Epoch 00033: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1769s 36ms/sample - loss: 1.7605 - val_loss: 2.7316
# Epoch 34/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7570
# Epoch 00034: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1722s 35ms/sample - loss: 1.7572 - val_loss: 2.7358
# Epoch 35/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7536
# Epoch 00035: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1687s 34ms/sample - loss: 1.7537 - val_loss: 2.7361
# Epoch 36/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7502
# Epoch 00036: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1696s 34ms/sample - loss: 1.7503 - val_loss: 2.7356
# Epoch 37/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7447
# Epoch 00037: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1708s 35ms/sample - loss: 1.7450 - val_loss: 2.7291
# Epoch 38/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7427
# Epoch 00038: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1739s 35ms/sample - loss: 1.7427 - val_loss: 2.7294
# Epoch 39/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7397
# Epoch 00039: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1766s 36ms/sample - loss: 1.7399 - val_loss: 2.7299
# Epoch 40/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7352
# Epoch 00040: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1742s 35ms/sample - loss: 1.7352 - val_loss: 2.7331
# Epoch 41/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7281
# Epoch 00041: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1748s 35ms/sample - loss: 1.7282 - val_loss: 2.7282
# Epoch 42/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7271
# Epoch 00042: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1734s 35ms/sample - loss: 1.7269 - val_loss: 2.7408
# Epoch 43/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7231
# Epoch 00043: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1752s 35ms/sample - loss: 1.7233 - val_loss: 2.7479
# Epoch 44/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7216
# Epoch 00044: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1726s 35ms/sample - loss: 1.7217 - val_loss: 2.7323
# Epoch 45/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7130
# Epoch 00045: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1725s 35ms/sample - loss: 1.7131 - val_loss: 2.7373
# Epoch 46/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7086
# Epoch 00046: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1729s 35ms/sample - loss: 1.7088 - val_loss: 2.7366
# Epoch 47/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7070
# Epoch 00047: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1726s 35ms/sample - loss: 1.7070 - val_loss: 2.7394
# Epoch 48/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7034
# Epoch 00048: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1729s 35ms/sample - loss: 1.7035 - val_loss: 2.7320
# Epoch 49/50
# 49408/49457 [============================>.] - ETA: 1s - loss: 1.7005
# Epoch 00049: saving model to /content/drive/MyDrive/Colab Notebooks/cp.ckpt
# WARNING:tensorflow:This model was compiled with a Keras optimizer (<tensorflow.python.keras.optimizers.RMSprop object at 0x7f3940974510>) but is being saved in TensorFlow format with `save_weights`. The model's weights will be saved, but unlike with TensorFlow optimizers in the TensorFlow format the optimizer's state will not be saved.
#
# Consider using a TensorFlow optimizer from `tf.train`.
# 49457/49457 [==============================] - 1730s 35ms/sample - loss: 1.7005 - val_loss: 2.7446
# Epoch 50/50
# 34816/49457 [====================>.........] - ETA: 8:14 - loss: 1.6830

# %%
os.listdir(checkpoint_dir)

# %%
# !pip install -U -q PyDrive
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

# 1. Authenticate and create the PyDrive client.
auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)

# 2. Save Keras Model or weights on google drive

# create on Colab directory
model.save('text_summary.h5')    
model_file = drive.CreateFile({'title' : 'text_summary.h5'})
model_file.SetContentFile('text_summary.h5')
model_file.Upload()

# download to google drive
drive.CreateFile({'id': model_file.get('id')})
# Out:
# GoogleDriveFile({'id': '1-NWSZ6TUsoBkV0La3-5IXqikaVtCzMBS'})

# %%
reverse_target_word_index=y_tokenizer.index_word
reverse_source_word_index=x_tokenizer.index_word
target_word_index=y_tokenizer.word_index

# Encode the input sequence to get the feature vector
encoder_model = Model(inputs=encoder_inputs,outputs=[encoder_outputs, state_h, state_c])

# Decoder setup
# Below tensors will hold the states of the previous time step
decoder_state_input_h = Input(shape=(latent_dim,))
decoder_state_input_c = Input(shape=(latent_dim,))
decoder_hidden_state_input = Input(shape=(max_text_len,latent_dim))

# Get the embeddings of the decoder sequence
dec_emb2= dec_emb_layer(decoder_inputs) 
# To predict the next word in the sequence, set the initial states to the states from the previous time step
decoder_outputs2, state_h2, state_c2 = decoder_lstm(dec_emb2, initial_state=[decoder_state_input_h, decoder_state_input_c])

#attention inference
attn_out_inf, attn_states_inf = attn_layer([decoder_hidden_state_input, decoder_outputs2])
decoder_inf_concat = Concatenate(axis=-1, name='concat')([decoder_outputs2, attn_out_inf])

# A dense softmax layer to generate prob dist. over the target vocabulary
decoder_outputs2 = decoder_dense(decoder_inf_concat) 

# Final decoder model
decoder_model = Model(
    [decoder_inputs] + [decoder_hidden_state_input,decoder_state_input_h, decoder_state_input_c],
    [decoder_outputs2] + [state_h2, state_c2])

def decode_sequence(input_seq):
    # Encode the input as state vectors.
    e_out, e_h, e_c = encoder_model.predict(input_seq)
    
    # Generate empty target sequence of length 1.
    target_seq = np.zeros((1,1))
    
    # Populate the first word of target sequence with the start word.
    target_seq[0, 0] = target_word_index['sostok']

    stop_condition = False
    decoded_sentence = ''
    while not stop_condition:
      
        output_tokens, h, c = decoder_model.predict([target_seq] + [e_out, e_h, e_c])

        # Sample a token
        sampled_token_index = np.argmax(output_tokens[0, -1, :])
        sampled_token = reverse_target_word_index[sampled_token_index]
        
        if(sampled_token!='eostok'):
            decoded_sentence += ' '+sampled_token

        # Exit condition: either hit max length or find stop word.
        if (sampled_token == 'eostok'  or len(decoded_sentence.split()) >= (max_headlines_len-1)):
            stop_condition = True

        # Update the target sequence (of length 1).
        target_seq = np.zeros((1,1))
        target_seq[0, 0] = sampled_token_index

        # Update internal states
        e_h, e_c = h, c

    return decoded_sentence

def seq2summary(input_seq):
    newString=''
    for i in input_seq:
        if((i!=0 and i!=target_word_index['sostok']) and i!=target_word_index['eostok']):
            newString=newString+reverse_target_word_index[i]+' '
    return newString

def seq2text(input_seq):
    newString=''
    for i in input_seq:
        if(i!=0):
            newString=newString+reverse_source_word_index[i]+' '
    return newString

# %%
for i in range(0,100):
    print("Review:",seq2text(x_tr[i]))
    print("Original summary:",seq2summary(y_tr[i]))
    print("Predicted summary:",decode_sequence(x_tr[i].reshape(1,max_text_len)))
    print("\n")
# Out:
# Review: attempt restore law order maintain peace south kashmir indian army blending operation 39 calm 39 operation 39 ki 39 magical hug reports said operation army personnel interacted locals encouraged restore normalcy south kashmir virtual 39 jungle raj 39 reportedly run militants
# Original summary: army gives 39 ki 39 for peace in kashmir
# Predicted summary:  j amp k army 39 s 39 39 ki kashmir released
#
#
# Review: 39 music cats 39 album comprising five cat friendly compositions topped itunes classical music chart cellist david allergic cats composed collection sounds aimed calm album released universal music reportedly becoming first major label release album human consumption n
# Original summary: 39 music for cats 39 tops music
# Predicted summary:  39 music 39 named most popular music album
#
#
# Review: reacting anonymous blog alleging viral fever tvf founder arunabh kumar molestation former female employee actor naveen tuesday said 100 sure blog fake anonymous blogger claimed told molestation laughed said 34 hai hota hai 34
# Original summary: 100 sure the blog is fake says on tvf row
# Predicted summary:  i 39 ve 100 fake says tvf says tvf row
#
#
# Review: iranian female bodybuilder arrested posting pictures muscles social media considered 39 nude 39 unnamed bodybuilder reportedly sent prison could pay bail 34 lakh notably iran 34 nude 34 refer woman reveals parts body must covered public
# Original summary: iranian female arrested for posting pics online
# Predicted summary:  iranian female arrested for posting pics of iran
#
#
# Review: german automaker volkswagen recall nearly 3 43 lakh diesel cars across 13 models india part global recall replace software helped vehicles fake pollution emission tests models recalled include polo vento audi a4 among others volkswagen paid 19 billion fines cheating emission tests
# Original summary: volkswagen to recall 3l cars in india over emissions scandal
# Predicted summary:  volkswagen cars emissions have emissions scandal
#
#
# Review: london airport recently revealed number objects confiscated daily basis included things like handcuffs bubble making gun horse food potato fondue tuna dog shampoo snow globes jams ​and spreads snow globes seized commonly two pairs handcuffs confiscated every month average
# Original summary: london airport reveals 39 39 seized items
# Predicted summary:  london airport enables tracking wearable
#
#
# Review: cabinet approved indian institute management amendment bill iims institutions national importance allowing award degrees students instead bill provides complete autonomy iims combined adequate accountability also provides periodic review institute 39 performance placing results public domain
# Original summary: cabinet approves bill to award degrees
# Predicted summary:  cabinet approves bill to award bill 2016
#
#
# Review: singer kanika kapoor cancelled five shows pakistan amid rising tension india neighbour 38 year old singer performed islamabad months ago said 34 people pakistan lovely feel sad world come stage people 34 called surgical strikes india 39 political thing 39
# Original summary: kapoor cancels five shows in pakistan
# Predicted summary:  kapoor 39 s 5 yr old pakistani man goes on pak
#
#
# Review: nasa friday announced selected blue origin help transport new technologies space reusable new shepard rocket blue origin sixth company get selected program offers ways transport technologies space six companies compete task orders deliver payload integration flight services
# Original summary: nasa blue origin partner for flight services
# Predicted summary:  nasa announces its own blue origin
#
#
# Review: inauguration newly built war memorial shaurya prime minister narendra modi friday likened defence minister army saying forces 39 say display valour 34 talk soldiers mostly uniform valour must also see example humanity 34 modi added
# Original summary: our army doesn 39 t speak but act so does our defence min pm
# Predicted summary:  army doesn 39 t speak but well defence pm modi
#
#
# Review: presenting union budget 2016 finance minister arun jaitley today announced 100 deduction profits three five years startups set april 2016 march 2019 government also allocated 500 crore sc st women entrepreneurs 39 start india 39 scheme enabled registration new companies one day
# Original summary: budget 2016 profit for startups
# Predicted summary:  budget 2016 to be 100 startups next year jaitley
#
#
# Review: actor shahid kapoor recent interview revealed 34 scared 34 daughter misha comes tells wants become actress 34 acting tough job 34 35 year old actor said misha born august 26 year first child shahid wife mira
# Original summary: i 39 ll be scared if my daughter wants to become an actress 39
# Predicted summary:  i want my daughter to get it shahid
#
#
# Review: french astronaut thomas pesquet shared picture wind sahara desert shot international space station 34 erosion wind clearly visible sahara desert paint flowed tens kilometres 34 pesquet tweeted astronaut six month mission earth orbiting spacecraft perform experiments space
# Original summary: astronaut shares view of sahara desert from space
# Predicted summary:  astronaut shares video of using space
#
#
# Review: ethiopia 39 government arrested 1 500 people since declaring state emergency two weeks ago restore peace following violent anti government protests according state controlled media notably people detained without warrants six month emergency first declaration emergency since ethiopia 39 ruling party came power 25 years ago
# Original summary: over 1 500 arrested since ethiopia declared emergency
# Predicted summary:  1 500 held in ethiopia over emergency violence
#
#
# Review: day rti revealed actress politician hema malini allotted land mumbai low prices 39 hema malini 39 top indian twitter trend friday users criticised veteran actress tweeting 34 unfortunate part deal shameless enough accept 34 34 39 misused position 34 another tweet read
# Original summary: 39 hema malini 39 trending on twitter today
# Predicted summary:  39 hema malini 39 trending on twitter today
#
#
# Review: finance minister arun jaitley sunday said nda government 34 still committed agenda governance 34 jammu kashmir statement comes bjp president amit shah met pdp chief mehbooba mufti delhi friday however agenda meeting remained unclear parties yet agree government formation state
# Original summary: committed to governance agenda in j amp k jaitley
# Predicted summary:  jaitley trying to change growth jaitley
#
#
# Review: chairing meeting water ministry review indus waters treaty pakistan prime minister narendra modi monday reportedly said 34 blood water 39 flow together time 34 india expedite construction three dams — dam dam dam — river chenab
# Original summary: blood water can 39 t flow together at same time modi
# Predicted summary:  water level in india can be a
#
#
# Review: 12 000 people moved safer places typhoon hit island philippines sunday officials said nearly 200 domestic international flights cancelled thousands passengers remain stranded inter island ordered stop operations two people reportedly died due typhoon
# Original summary: 12 000 people flee as typhoon hits philippines
# Predicted summary:  12 000 people flee as typhoon hits philippines
#
#
# Review: meeting point river lake venezuela witnesses average 28 lightning flashes minute monsoon 39 lightning 39 phenomenon recognised guinness 39 highest concentration lightning 39 250 lightning flashes per square kilometre yearly experts believe lightning caused abundance methane oil fields
# Original summary: a spot in venezuela is struck by lightning 28 times a minute
# Predicted summary:  sea found in sea after highest lightning sea
#
#
# Review: forensic examination concluded remains two terrorists found pathankot attack debris confirming six terrorists attacked air base conflicting reports regarding number four bodies found immediately attack home minister rajnath singh later claimed charred remains apart four terrorists 39 bodies found
# Original summary: 6 terrorists attacked pathankot report
# Predicted summary:  pathankot attack on pathankot attack
#
#
# Review: government looking harness india 39 50 000 km sea river fronts waterways mulling various ways raise around 70 000 crore develop stretches union minister nitin gadkari said sunday statement comes parliament last week passed bill declare 111 rivers across country national waterways
# Original summary: govt eyes 50k km of sea river
# Predicted summary:  govt to develop 50k 000 km of sea
#
#
# Review: two malls bengaluru orion mall arcade mall nagar encroached drains survey revealed permissions granted malls 39 construction structure still come survey said comes city 39 civic body directed karnataka high court look matter
# Original summary: 2 bengaluru have survey
# Predicted summary:  bengaluru to get 50 mumbai and survey
#
#
# Review: external affairs ministry 39 spokesperson vikas swarup friday rejected pakistan 39 claims 39 fresh 39 letter sent new delhi seeking 39 additional evidence 39 draw early conclusion 26 11 mumbai attacks investigation pakistan far arrested seven lashkar linked militants including mastermind rehman lakhvi role 2008 attacks
# Original summary: govt denies receiving pak letter on 26 11 probe
# Predicted summary:  pak denies report on india 39 s isi links
#
#
# Review: aam aadmi party aap thursday released first list 19 candidates upcoming punjab assembly elections singh shergill contest nagar constituency party youth wing president singh bains constituency advocate hs phoolka constituency polls scheduled held 2017
# Original summary: aap releases 1st list of candidates for punjab polls
# Predicted summary:  aap releases list of candidates for punjab polls
#
#
# Review: addressing nation eve india 39 70th independence day president pranab mukherjee expressed concern recent violence dalits 34 attacks weaker sections need dealt firmly 34 said adding 34 india’s remarkable growth story continue uninterrupted 34 said 34 forces intolerance 34 erupted india last four years
# Original summary: 39 attacks on to be 39
# Predicted summary:  39 39 india prez should be on india prez
#
#
# Review: 15 000 residents philippines 39 capital manila lost homes fire broke tuesday raged overnight officials said seven people suffered minor injuries fire reportedly started due faulty power line three evacuation centres opened house 3 000 families lost homes
# Original summary: 15 000 people lose homes in philippines fire
# Predicted summary:  15 000 people killed in philippines fire
#
#
# Review: us based startup developed smart reverse water purifier 39 39 displays purification levels reminds user stay controlled app 3 litre capacity purifier need plumbing installation lets user select amount water dispensed app also alerts user timely exchange filters
# Original summary: startup makes portable smart water
# Predicted summary:  smart water turns out into a
#
#
# Review: indian troops sunday killed three terrorists encounter tangdhar area j amp kupwara district entire area cordoned security reasons slain terrorists involved august 19 attack three bsf personnel injured army recovered three weapons war like stores arms dead terrorists
# Original summary: army kills 3 terrorists in kupwara encounter
# Predicted summary:  indian army kills 3 terrorists in kupwara encounter
#
#
# Review: ship belonging geological survey india gsi found 75 pieces wreckage suspected missing indian air force 39 32 200 nautical miles chennai coast truth pieces spotted camera installed ship could established analysing laboratory gsi said
# Original summary: 75 suspected pieces of iaf 39 s missing an 32 found
# Predicted summary:  india found in 2014 blast case in iaf
#
#
# Review: new promotional video first episode 39 koffee karan 39 actor shah rukh khan asked 39 kill person kissed daughter replied 34 39 rip lips 34 khan along actress alia bhatt feature first episode fifth edition show hosted filmmaker karan johar
# Original summary: i 39 ll the off the man who my daughter srk
# Predicted summary:  39 srk 39 s first look from 39 srk 39 s 39 out
#
#
# Review: actress sonam kapoor talking molested revealed told school teachers incident said groping molestation added 34 thought rape molestation 34 sonam earlier revealed man come behind held breasts movie theatre 13
# Original summary: was told is not molestation when i was 13 sonam
# Predicted summary:  i was told i was a i was told i 39 m a molestation
#
#
# Review: australian captain steve smith along rounders shane watson james faulkner set use heavier bats world t20 game new zealand friday respective bat manufacturers requested heavier bats citing india 39 low bouncing pitches move comes kiwis defeated india spin attack opening game
# Original summary: aus opt for bats to face nz spin attack
# Predicted summary:  smith to get bat with world 39 s ball
#
#
# Review: demonetisation old 500 1 000 notes move pm modi us india business council said pm modi taken leadership rest world follow soon president mukesh said modi took 34 bold decision 34 even though 34 politically risky 34 added
# Original summary: demonetisation a bold and move us india biz council
# Predicted summary:  pm modi is the nation of india says demonetisation
#
#
# Review: four minute video explains artificial intelligence machine tested capabilities states must pass 39 turing test 39 test requires computer chat human seemingly human like manner adds intelligent machines able interpret visual information traits like decision making
# Original summary: video explains what is artificial intelligence
# Predicted summary:  video explains how to curb artificial intelligence
#
#
# Review: puducherry lieutenant governor kiran bedi saturday said would quit post may next year completion two years office comes day congress mlas wrote centre complaining style functioning earlier cancelled cm v narayanasamy 39 order banning officials using social media official communication
# Original summary: will quit puducherry l g post in may 2018 kiran bedi
# Predicted summary:  kiran bedi will be quit next year bedi
#
#
# Review: reacting angelina jolie filing divorce brad pitt user tweeted 34 today shall go day love died 34 another tweet read 34 39 worry guys angelina 39 brad pitt adopt 34 referring brad 39 ex wife jennifer aniston user tweeted 34 angelina brad getting divorced jennifer wins 10 points gryffindor 34
# Original summary: today go down as the day love died tweets user
# Predicted summary:  39 39 tweets user on love day
#
#
# Review: delhi deputy cm manish sisodia sunday said aap accept resignation legislator amanatullah khan molestation charges levelled sister law fir registered sisodia added “whatever happening khan family’s internal matter ” notably khan earlier arrested july charges molestation
# Original summary: will not accept resignation aap
# Predicted summary:  aap must be says sisodia
#
#
# Review: two day mock assembly session 34 vidarbha state 34 held vidarbha rajya andolan samiti next month demand formation separate state symbolic session held ahead winter session maharashtra assembly mock session expected bring resolution oppose maharashtra legislature officials said
# Original summary: mock assembly session to demand vidarbha state
# Predicted summary:  two day session amid jat protests
#
#
# Review: cast film 39 moonlight 39 named best picture oscars featured latest underwear advertisements american fashion house calvin klein mahershala ali rhodes ashton sanders alex modelled spring 2017 men 39 campaign new advertisement campaign features black white photos cast members
# Original summary: cast of oscar winning film 39 39 in calvin ads
# Predicted summary:  39 39 named best film at oscars 2017
#
#
# Review: model padma lakshmi written book includes details married life ex husband novelist salman rushdie lakshmi also hosted tv show 39 top chef 39 titled 39 love loss ate 39 rushdie needed constant care feeding frequent sex 39 insensitive 39 came intercourse revealed lakshmi 20 years younger rushdie
# Original summary: padma lakshmi pens book on marriage with
# Predicted summary:  padma shri awardee book 39 s son to book
#
#
# Review: actress sonakshi sinha said industry 39 dabangg 39 34 noticed dabangg it’s first film even need guest appearance role 34 said sonakshi added 39 dabangg 3 39 features character 39 39 continue play role
# Original summary: i am what i am because of sonakshi
# Predicted summary:  i am not a good for the first time sonakshi
#
#
# Review: inspired captain gautam gambhir 39 unbeaten 90 60 balls kolkata knight riders defeated sunrisers hyderabad eight wickets ipl saturday batting first hyderabad posted 142 7 20 overs eoin morgan scoring 51 43 umesh yadav took 3 28 kolkata reached target 18 2 overs robin uthappa 39 38 34 assisting gambhir
# Original summary: kolkata defeat hyderabad by 8 wickets
# Predicted summary:  gambhir defeat sa in hyderabad
#
#
# Review: centre’s fiscal deficit difference expenditure revenue rose 3 93 lakh crore nearly 74 full year target april july data released government wednesday stated 69 3 budget estimates year ago period notably revenue deficit climbed 93 1 budget estimates government continued public spending
# Original summary: fiscal deficit at 74 of full year target in july
# Predicted summary:  fiscal deficit at target of 3 3 cr in apr aug
#
#
# Review: odisha cm naveen patnaik saturday said state government would set 38 000 micro small medium enterprises msme units providing employment one lakh people state government also develop five food processing corridors ten livelihood business incubators ten village industries clusters odisha khadi village industries board added
# Original summary: will 38 000 units in odisha
# Predicted summary:  odisha govt to set up odisha govt
#
#
# Review: 39 luv letter 39 first song arshad warsi aditi rao hydari boman irani starrer 39 legend michael mishra 39 released monday picturised lead actress aditi song composed meet bros sung meet bros along kanika kapoor directed manish jha film release august 5
# Original summary: first song from the legend of michael mishra out
# Predicted summary:  first song from 39 the legend of michael mishra 39 out
#
#
# Review: congress tuesday demanded disqualification 21 aap mlas appointed parliamentary secretaries president refused assent delhi government bill aiming retrospective exemption disqualification congress spokesperson pl punia alleged chief minister arvind kejriwal making false claims issue asked resign taking moral responsibility
# Original summary: cong demands of 21 aap mlas
# Predicted summary:  cong demands aap mlas to clear aap 39 s aap
#
#
# Review: per reports actor rajinikanth set earn 80 crore total remuneration latest film 39 kabali 39 making highest paid actor india paid 35 crore remuneration film 39 budget 110 crore also reportedly get 45 crore share film 39 collection box office
# Original summary: rajinikanth earns 80 crore for kabali report
# Predicted summary:  rajinikanth earns 80 crore in kabali report
#
#
# Review: manchester city defeated sunderland 1 0 premier league stadium light tuesday sergio aguero 39 goal 16th minute jesus cross gave away side three points win city sits second table three points behind leicester city sunderland 19th spot
# Original summary: manchester city beat sunderland 1 0
# Predicted summary:  manchester city beat manchester city in 1 0
#
#
# Review: government said proposed vehicle scrapping policy generate steel scrap worth 11 500 crore every year help reduce india’s import burden improve foreign exchange reserves added voluntary vehicle fleet modernisation programme offer incentives worth 8 12 cost new vehicle old one
# Original summary: 39 vehicle plan can get steel worth 11 5k cr yr 39
# Predicted summary:  govt asks steel to invest 11 cr in steel
#
#
# Review: austria 39 parliament tuesday announced turkish islamist hackers 39 group claimed responsibility cyber attack brought website 20 minutes last week 34 reaction harsh racism austria muslims parliament 34 group posted facebook page similar attack targetting austrian defence ministry took place last year
# Original summary: turkish islamist hackers claim austrian parliament hacking
# Predicted summary:  parliament passes turkey 39 s cyber attack
#
#
# Review: indian stock markets emerged top preference investments among global institutional investors asia pacific region results credit suisse survey showed monday australia china h securities listed hong kong stock exchange next two popular choices 320 companies 15 countries participated survey
# Original summary: indian markets most preferred credit suisse
# Predicted summary:  indian stock exchange markets for most foreign survey
#
#
# Review: serbia 39 novak djokovic face france 39 monfils 10th straight us open semifinal jo wilfried tsonga 39 injury withdrawal second straight instance injury withdrawal serbian monfils yet drop set tournament reached first grand slam semi final eight years defeating compatriot lucas 6 4 6 3 6 3
# Original summary: djokovic to face in us open semis
# Predicted summary:  djokovic to face murray in us open semis
#
#
# Review: canadian technology company blackberry sell another phone trademark physical keyboard confirmed ceo john chen 34 one keyboard phone promised people 39 coming 34 said interview last week company officially stopped making phones license blackberry brand companies
# Original summary: blackberry ceo promises last keyboard phone
# Predicted summary:  blackberry ceo phone to have a phone says ceo
#
#
# Review: 25th january celebrated national voters 39 day throughout india every year date declared national voters 39 day year 2011 election commission india founded 25 january 1950 day aims increasing enrolment voters especially encourage participation newly eligible young voters ensure universal adult franchise
# Original summary: why is the national voters 39 day observed on january 25
# Predicted summary:  39 39 india to hold national award
#
#
# Review: protests high tuition fees south africa 39 university escalated students attacked police rocks tuesday police used rubber bullets tear gas disperse protesters protests first erupted last year government froze fee increases however unrest started government commission decided fees would continue rise
# Original summary: student protesters clash with police in south africa
# Predicted summary:  south africa student protesters clash at police
#
#
# Review: former afghan president hamid karzai criticised us president barack obama authorising us troops launch counter insurgency attacks afghanistan asking 34 39 sovereign country 34 contradicts president ashraf ghani 39 agenda welcoming us political military support afghanistan us relation 34 partnership 34 34 master slave relationship 34 karzai added
# Original summary: aren 39 t we a country asks ex afghan prez
# Predicted summary:  obama will afghan prez afghanistan prez
#
#
# Review: physical training pt exam class ix students chacha nehru hindi high school maharashtra 39 bhiwandi asked students cricketer virat kohli’s school kept priyanka anushka deepika options exam students select right name exam conducted october 13
# Original summary: who is virat kohli’s girlfriend asks maha school in exam
# Predicted summary:  anurag kashyap 39 s exam school exam
#
#
# Review: 60 year old delhi based artist alka mathur makes art using tea bags also writes exhibition titled 39 tea time blue sky 39 mathur display 40 works featuring paintings journal entries tea bags show scheduled till november 30 bikaner house road new delhi
# Original summary: delhi based artist makes art using tea bags
# Predicted summary:  delhi based artist makes art using art
#
#
# Review: bombay high court tuesday slammed 4 500 resident doctors maharashtra gone mass leave since march 20 asked join work face action management hc hearing pil filed strike wherein advocate representing petitioners claimed 58 people died maharashtra since monday
# Original summary: join work or face action bombay hc to protesting doctors
# Predicted summary:  4 500 dalit 500 doctors not to be maha hc
#
#
# Review: archaeologists uncovered almost 700 ceramic glass bottles containing heart disease drugs istanbul district professor said plants found nearby formed 34 core many drugs 34 said surrounding area could also provide evidence fire caused empire attacked settlement 626 ad
# Original summary: archaeologists find bottles with in istanbul
# Predicted summary:  egypt court develops 700 700 kg cocaine
#
#
# Review: according reports actor sunny deol launch son karan 39 39 sequel 1983 film 39 39 sunny 39 debut film opposite amrita singh sunny reportedly wanted cast amrita 39 daughter sara khan opposite karan however amrita turn offer sara already signed contract karan johar 39 39 dharma productions 39
# Original summary: sunny to launch son in 39 again 39 reports
# Predicted summary:  sunny to launch campaign on son 39 s debut reports
#
#
# Review: american president barack obama wednesday said 34 big nations bully smaller ones 34 discussing south china sea row visit vietnam obama also called territorial disputes resolved peacefully even vietnam china among nations made claims sovereignty south china sea
# Original summary: big nations should not smaller obama
# Predicted summary:  nations must be big b china sea obama
#
#
# Review: actor rahul khanna written 34 breaking 34 british airways claiming airline repeatedly lost luggage khanna said together 20 years adding 34 dear ba first 34 travelled alone first time airline wrote 34 gave heart return lost luggage 34
# Original summary: rahul khanna writes about break up with british airways
# Predicted summary:  rahul gandhi 39 s british airways flight
#
#
# Review: telecom department favour giving penal power telecom regulatory authority india allowing fine telecom operators poor services like call drops according reports however favour two year imprisonment power sought trai proposal reportedly submitted telecom minister 39 approval
# Original summary: 39 telecom dept favours more power to trai 39
# Predicted summary:  trai proposes telecom dept to reduce telecom operators
#
#
# Review: hours bjp haryana minister anil vij said pm narendra modi better brand mahatma gandhi hindu mahasabha meerut president bharat rajput urged centre remove mahatma gandhi’s picture currency notes removing mahatma gandhi’s picture khadi first good work done government last 70 years added n
# Original summary: remove gandhi’s pic from currency hindu mahasabha leader
# Predicted summary:  modi must allow currency notes haryana cm
#
#
# Review: turkish parliament thursday granted immunity prosecution members armed forces part counter terrorism operations new law gives powers military turkey midst insurgency kurdistan workers party pkk last year two year long ceasefire pkk turkish government collapsed
# Original summary: turkey immunity for security forces
# Predicted summary:  turkey denies to law on turkey
#
#
# Review: initiative protect wildlife habitat resort operating without wildlife environmental clearances forest karnataka 39 belagavi district demolished according reports step taken many notices sent forest department revenue authorities located within eco sensitive zone wildlife sanctuary
# Original summary: illegal forest resort demolished to protect wildlife
# Predicted summary:  39 39 foot covered with forest with endangered
#
#
# Review: toss harare test pakistan zimbabwe january 31 1995 done twice pakistan captain saleem malik called 39 bird 39 instead heads tails coin eagle zimbabwe 39 national bird inscribed one side malik opted bat 39 bird 39 turned match referee refused acknowledge call
# Original summary: pak captain once called bird instead of head or tail in toss
# Predicted summary:  pak batsman once called bird flu instead of bird flu
#
#
# Review: government tuesday said shortage food grains implement food security india national food security act food public distribution minister ram vilas paswan said stock food grains central pool july 1 540 lakh tonnes buffer norm 411 lakh tonnes
# Original summary: 39 no lack of food to enforce food security 39
# Predicted summary:  food security food security act govt to food
#
#
# Review: india 39 biggest cigarette maker itc monday said resumed production phases complying new rules prescribed covering 85 cigarette packets pictorial warnings company shut plants may 4 comply new standards notably petitions challenging government 39 decision pending karnataka high court n
# Original summary: itc resumes cigarette production with new norms
# Predicted summary:  itc shuts down cigarette cigarette production
#
#
# Review: pakistan pm nawaz sharif written un secretary general ban ki moon second time month probe alleged human rights violations kashmir pakistani official said thursday letter reportedly also slams pm narendra modi 39 remarks balochistan pok notably india refusing allow international involvement resolving kashmir issue
# Original summary: pak pm writes 2nd letter to un on kashmir issue
# Predicted summary:  pak pm 39 s un ban on un ban on kashmir
#
#
# Review: pearl harbor attack surprise aerial attack japan us naval base pearl harbor december 7 1941 attack intended keep us pacific fleet interfering japanese military action southeast asia attacks killed 2 400 us servicemen civilians forced entry world war ii
# Original summary: what was the pearl attack
# Predicted summary:  japan attack out of japanese attack
#
#
# Review: automation threatens disrupt 69 jobs india world bank said adding traditional economic path developing countries may disturbed technological development 34 know technology continue fundamentally reshape world 34 world bank president jim kim said bank also said china may lose 77 jobs automation
# Original summary: automation threatens 69 jobs in india world bank
# Predicted summary:  world bank cuts loan rates by 0 to
#
#
# Review: inter level exam bihar staff selection commission bssc wednesday cancelled question paper leak chief minister nitish kumar 39 approval special investigation team constituted probe allegations question paper leak submitted report chief secretary director general police dgp
# Original summary: bihar exam cancelled over question paper leak
# Predicted summary:  bihar board slams bihar for leak at question paper
#
#
# Review: team researchers university maryland made transparent wood claim stronger glass manufacture wood team removed lignin – gives wood color – wood coated class reactive make stronger glass
# Original summary: team makes transparent wood stronger than glass
# Predicted summary:  scientists develop wood film
#
#
# Review: bollywood actress sunny leone tuesday posted video facebook thanking fans followers supporting interview went viral wherein interviewer allegedly insulted 34 feel really needs said right thank love everyone support 34 leone captioned video
# Original summary: sunny leone thanks supporters on facebook
# Predicted summary:  sunny leone thanks fans for video on facebook
#
#
# Review: ryan gosling emma stone starrer 39 la la land 39 people’s choice award toronto international film festival tiff 2016 dev patel nicole kidman starrer 39 lion 39 came second mira 39 queen 39 starring lupita nyong 39 madina ranked third meanwhile natalie portman starrer 39 jackie 39 platform prize tiff
# Original summary: 39 la la land 39 wins choice award at tiff
# Predicted summary:  la la land wins 39 la land 39 to be screened at film fest
#
#
# Review: woman whose minor daughter allegedly gang raped four men shot outside house delhi’s jamia nagar friday reportedly shot biker way local hospital 16 year old daughter per reports woman undergoing treatment aiims trauma centre
# Original summary: rape victim 39 s mother shot at in delhi
# Predicted summary:  woman gets daughter 39 s gang rape in delhi
#
#
# Review: miss india 2012 pageant winner mishra co founded fashion discovery startup monday raised 1 crore group seven high net worth individuals founded 2016 mishra gupta startup aggregates products online offline private fashion labels competes fashion startups wooplr
# Original summary: ex miss india mishra 39 s fashion startup raises 1 crore
# Predicted summary:  india 39 s miss fashion startup raises 1 crore
#
#
# Review: commenting harbhajan singh 39 tweet indian pitches 39 conditions sourav ganguly said harbhajan 34 take easy 34 34 move ahead 34 harbhajan claimed wicket tally would 34 something else 34 bowled pitches india played recently 34 39 pitches ashwin 39 fault harbhajan great bowler enjoy cricket leave 34 added ganguly
# Original summary: harbhajan singh should move on sourav ganguly
# Predicted summary:  harbhajan singh to move sc against india 39 s 39 39
#
#
# Review: google conference wednesday company announced several new features firebase – cloud services provider offers dedicated platform building mobile apps acquired google 2014 firebase supports ios android web offer analytics portal cloud messaging service database hosting authentication crash reporting services
# Original summary: google announces new features for its 39 39
# Predicted summary:  google announces new features on android n
#
#
# Review: pirates reportedly hijacked oil tanker coast somalia first incident involving large commercial vessel since 2012 vessel eight sri lankan crew members board carrying fuel djibouti mogadishu reports added notably four attempted attacks somali pirates last three years
# Original summary: pirates oil tanker off somalia 39 s coast
# Predicted summary:  pirates oil tanker off somalia 39 s coast
#
#
# Review: makeup artist bobbi brown said 39 39 process enhancing facial structure cosmetics 34 firmly 34 34 never much can’t make face don’t 34 added notably also founder skincare products cosmetics range 39 bobbi brown 39
# Original summary: is out makeup artist brown
# Predicted summary:  artist makes art of living on her
#
#
# Review: united arab emirates saturday urged citizens wear national dress abroad alerted women countries whose laws prohibit face covers uae businessman traditional garb detained us recently islamic state suspect uae 39 traditional garb men comprises white headscarf headband
# Original summary: uae asks citizens to avoid national dress abroad
# Predicted summary:  uae asks citizens to make dress code calls to immigrants
#
#
# Review: two minute video explains working leap year maintains gap calendar year true year earth takes 365 24 days revolve around sun therefore every four years add extra quarters stick extra day february leap year concept julius caesar 39 idea video claims
# Original summary: video explains how a leap year works
# Predicted summary:  video explains how to make the day of 2016
#
#
# Review: thailand 39 crown prince maha vajiralongkorn next line thai throne given pet rank air chief marshal country 39 air force 64 year old married least three times reportedly planning marry former flight attendant recently vajiralongkorn photographed wearing crop top saluting officers germany
# Original summary: thai prince made his pet dog an air chief
# Predicted summary:  thailand 39 s thailand king welcomes thai prince 39 s air force
#
#
# Review: seven world 39 biggest banks including bank america jpmorgan tuesday agreed pay 324 million settle us lawsuit accusing manipulating interest rate benchmark derivatives markets companies investors use benchmark interest rates price swaps transactions commercial real estate mortgages structured debt securities
# Original summary: 7 banks settle us rate case for mn
# Predicted summary:  bank of the world bank employees
#
#
# Review: pornhub partnership launched new virtual reality vr section users view vr content free desktop browser mobile browser android ios apps vr headsets like oculus rift celebrate launch company also giving away 10 000 google cardboard vr goggles viewers
# Original summary: pornhub launches new virtual reality section
# Predicted summary:  oracle launches vr app for vr
#
#
# Review: uk based researchers found ring galaxies expanding faster predicted einstein 39 theory study claims milky way neighbouring galaxy came close range causing galaxies ring scatter like 34 mini big bang 34 einstein 39 theory correct two galaxies would never come close researcher added
# Original summary: new study on galaxies challenges einstein 39 s theory
# Predicted summary:  scientists find new universe 39 s milky way
#
#
# Review: delhi health minister satyendar jain said delhi residents avail free mri pet ct scan 21 private laboratories people required show referral letter selected government hospitals state run avail facility tests considered costly delhi government making free added n
# Original summary: delhi residents can get free at 21 labs
# Predicted summary:  delhi govt schools to provide free in delhi
#
#
# Review: tourism ministry sanctioned 20 crore promoting tourism varanasi projects grant include sound light show buddha theme park sarnath conservation temples markandey infrastructure projects approved ministry 39 central sanctioning monitoring committee
# Original summary: govt sanctions 20 cr for varanasi tourism
# Predicted summary:  govt sanctions 20 cr for tourism varanasi
#
#
# Review: net profit nifty 50 companies likely grow 6 year year second quarter 2016 17 highest eight quarters report brokerage motilal said performance driven domestic like automobiles cement select private sector banks also consumer likely post healthy growth report claimed
# Original summary: nifty 50 companies 39 net profit to grow by 6 in q2 report
# Predicted summary:  nifty end trade on a flat note
#
#
# Review: according socialcops 39 analysis pradhan mantri jan dhan yojana data number bank accounts opened scheme increased 55 5 2015 2016 21 31 crore accounts march 16 2016 compared 13 68 crore accounts february 28 2015 notably quarter total accounts balance 0
# Original summary: number of jan dhan accounts up by 55 5
# Predicted summary:  5 yrs since jan dhan accounts in 5 years
#
#
# Review: rebel party workers saturday congress bhavan agartala protest suspension party mla sudip roy barman alleged anti party activities protesters attacked posters rahul gandhi sonia gandhi calling traitors contended burman 39 suspension protest congress cpi alliance west bengal anti democratic
# Original summary: rebel workers tripura congress office
# Predicted summary:  rebel workers protest congress in bihar
#
#
# Review: sports ministry wednesday approved registration proposed boxing federation india agreed hold formal elections body comes international boxing association issued warning indian boxing federation conducting elections failure would resulted indian boxers denied participation rio olympics
# Original summary: govt gives nod to new boxing registration
# Predicted summary:  govt approves proposal to appoint boxing to boost boxing polls
#
#
# Review: akhil bharatiya jat aarakshan samiti national president yashpal malik said association launch state wide 39 jat rally 39 haryana june 5 cm bhupinder singh hooda failed fulfill promises malik added release people arrested jat agitation compensation victims promised earlier
# Original summary: jat body to hold rally from june 5 in haryana
# Predicted summary:  jat agitation should be launched soon prez
#
#
# Review: kanyakumari set become first female honoured 39 sangita 39 title madras music academy title considered prestigious award carnatic music conferred kanyakumari january 1 2017 34 kanyakumari top ranking carnatic whose experience spans 50 years 34 said academy 39 president n murali
# Original summary: 1st woman chosen for
# Predicted summary:  1st female to get female award
#
#
# Review: young dolphin recently died dehydration beach argentina crowd continued clicking pictures creature outside water dolphin spotted people beach resort following grabbed put back sea authorities condemned death 39 vulnerable 39 dolphin species
# Original summary: dies of as crowd pics
# Predicted summary:  dies of 39 s
#
#
# Review: bengaluru police arrested school teacher allegedly raping student earlier got fired charges sexual harassment reports said identified pasha 28 year old teacher allegedly took victim hotel room coffee laced drink raped forced take contraceptive pill regaining consciousness n
# Original summary: bengaluru school teacher arrested for raping a student
# Predicted summary:  bengaluru school teacher arrested for raping woman
#
#
# Review: defending champions spain lost uefa euro round 16 tie italy 0 2 stade de france saint denis giorgio pelle scored italy either half italy booked place euro quarter finals germany became first player score spain euro knockout game since 2000
# Original summary: spain crash out of after 0 2 loss to italy
# Predicted summary:  spain loses 16 italy after 2 years

# %% [markdown]
# #### Rogue

# %%
# !pip install sumeval
# !python -m spacy download en
# Out:
# Collecting sumeval
#   Downloading sumeval-0.2.2.tar.gz (80 kB)
#      |████████████████████████████████| 80 kB 7.2 MB/s
# Requirement already satisfied: plac>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from sumeval) (1.1.3)
# Collecting sacrebleu>=1.3.2
#   Downloading sacrebleu-2.0.0-py3-none-any.whl (90 kB)
#      |████████████████████████████████| 90 kB 11.7 MB/s
# Requirement already satisfied: tabulate>=0.8.9 in /usr/local/lib/python3.7/dist-packages (from sacrebleu>=1.3.2->sumeval) (0.8.9)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from sacrebleu>=1.3.2->sumeval) (1.21.6)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from sacrebleu>=1.3.2->sumeval) (2019.12.20)
# Collecting colorama
#   Downloading colorama-0.4.4-py2.py3-none-any.whl (16 kB)
# Collecting portalocker
#   Downloading portalocker-2.4.0-py2.py3-none-any.whl (16 kB)
# Building wheels for collected packages: sumeval
#   Building wheel for sumeval (setup.py) ... done
#   Created wheel for sumeval: filename=sumeval-0.2.2-py3-none-any.whl size=54549 sha256=5f3df4e2cec61d839875a54ba8a6940a32fb131fbbd1b3db404b84dcdb20b4be
#   Stored in directory: /root/.cache/pip/wheels/f4/3f/31/c521bdfba2be7518bd94ba3e8b982812822167cc0497fad192
# Successfully built sumeval
# Installing collected packages: portalocker, colorama, sacrebleu, sumeval
# Successfully installed colorama-0.4.4 portalocker-2.4.0 sacrebleu-2.0.0 sumeval-0.2.2
# Collecting en_core_web_sm==2.2.5
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-2.2.5/en_core_web_sm-2.2.5.tar.gz (12.0 MB)
#      |████████████████████████████████| 12.0 MB 14.7 MB/s
# Requirement already satisfied: spacy>=2.2.2 in /usr/local/lib/python3.7/dist-packages (from en_core_web_sm==2.2.5) (2.2.4)
# Requirement already satisfied: plac<1.2.0,>=0.9.6 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.1.3)
# Requirement already satisfied: murmurhash<1.1.0,>=0.28.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.7)
# Requirement already satisfied: numpy>=1.15.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.21.6)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (57.4.0)
# Requirement already satisfied: wasabi<1.1.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.9.1)
# Requirement already satisfied: tqdm<5.0.0,>=4.38.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (4.64.0)
# Requirement already satisfied: preshed<3.1.0,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.6)
# Requirement already satisfied: srsly<1.1.0,>=1.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.5)
# Requirement already satisfied: thinc==7.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (7.4.0)
# Requirement already satisfied: cymem<2.1.0,>=2.0.2 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.0.6)
# Requirement already satisfied: requests<3.0.0,>=2.13.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (2.23.0)
# Requirement already satisfied: catalogue<1.1.0,>=0.0.7 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (1.0.0)
# Requirement already satisfied: blis<0.5.0,>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from spacy>=2.2.2->en_core_web_sm==2.2.5) (0.4.1)
# Requirement already satisfied: importlib-metadata>=0.20 in /usr/local/lib/python3.7/dist-packages (from catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.11.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.8.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=0.20->catalogue<1.1.0,>=0.0.7->spacy>=2.2.2->en_core_web_sm==2.2.5) (4.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2021.10.8)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (1.24.3)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (3.0.4)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3.0.0,>=2.13.0->spacy>=2.2.2->en_core_web_sm==2.2.5) (2.10)
# ✔ Download and installation successful
# You can now load the model via spacy.load('en_core_web_sm')
# ✔ Linking successful
# /usr/local/lib/python3.7/dist-packages/en_core_web_sm -->
# /usr/local/lib/python3.7/dist-packages/spacy/data/en
# You can now load the model via spacy.load('en')

# %%
from sumeval.metrics.rouge import RougeCalculator

def eval_rouges(refrence_summary, model_summary):
    rouge = RougeCalculator(stopwords=True, lang="en")

    rouge_1 = rouge.rouge_n(
                summary=model_summary,
                references=refrence_summary,
                n=1)

    rouge_2 = rouge.rouge_n(
                summary=model_summary,
                references=[refrence_summary],
                n=2)
    
    rouge_l = rouge.rouge_l(
                summary=model_summary,
                references=[refrence_summary])
    
    # You need spaCy to calculate ROUGE-BE
    
    rouge_be = rouge.rouge_be(
                summary=model_summary,
                references=[refrence_summary])


    return rouge_1, rouge_2,rouge_l,rouge_be

# %%
from xml.etree.ElementTree import Element, SubElement, Comment
top = Element('ZakSum')

comment = Comment('Generated by Amr Zaki')
top.append(comment)

# %%
  from functools import reduce

# %%
rouge_1_arr  = []
rouge_2_arr  = []
rouge_L_arr  = []
rouge_be_arr = []
i = 0
#for summ, longr in zip(summaries_val['short'], longreview_val['long']):#
for summ, longr in zip(y_tr, x_tr):#
  i = i  + 1
  print(i)
  print(" ")
  example = SubElement(top, 'example')
  rouge_1, rouge_2,rouge_L,rouge_be = eval_rouges(seq2summary(summ),decode_sequence(longr.reshape(1,max_text_len)))#
  
  eval_element = SubElement(example, 'eval')
  ROUGE_1_element  = SubElement(eval_element, 'ROUGE_1' , {'score':str(rouge_1)})
  ROUGE_2_element  = SubElement(eval_element, 'ROUGE_2' , {'score':str(rouge_2)})
  ROUGE_L_element  = SubElement(eval_element, 'ROUGE_l' , {'score':str(rouge_L)})
  ROUGE_be_element  = SubElement(eval_element,'ROUGE_be', {'score':str(rouge_be)})

  rouge_1_arr.append(rouge_1) 
  rouge_2_arr.append(rouge_2) 
  rouge_L_arr.append(rouge_L) 
  rouge_be_arr.append(rouge_be) 
  
  

print(rouge_1_arr)
rouge_1_avg = str(reduce(lambda x, y: x + y,  rouge_1_arr) / len(rouge_1_arr))
rouge_2_avg = str(reduce(lambda x, y: x + y,  rouge_2_arr) / len(rouge_2_arr))
rouge_3_avg = str(reduce(lambda x, y: x + y,  rouge_L_arr) / len(rouge_L_arr))
rouge_4_avg = str(reduce(lambda x, y: x + y, rouge_be_arr) / len(rouge_be_arr))

print(rouge_1_avg)
print(rouge_2_avg)
print(rouge_3_avg)
print(rouge_4_avg)
